# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from pylab import savefig
import glob
from IPython.display import display
import os
import sys
from datetime import date
import json
import numpy as np
import scipy
#import pingouin as pg

# %%
cwd = os.getcwd()
PLOTS_PATH = './Plots/'
ANALYSIS_RESULTS = './Results/'
os.makedirs(os.path.dirname(cwd + PLOTS_PATH), exist_ok=True)
os.makedirs(os.path.dirname(cwd + ANALYSIS_RESULTS), exist_ok=True)

# %%
familiarity_df = pd.read_csv(f'{cwd}/Familiarity_Questionnaire.csv')

display(familiarity_df)
# Out:
#               Timestamp Unnamed: 1  Gender  Age    Handedness  \
# 0   11/17/2021 17:21:34       P002  Female   21  Right-handed
# 1   11/18/2021 17:21:02       P003  Female   23  Right-handed
# 2   11/19/2021 18:30:23       P004    Male   29  Right-handed
# 3    12/2/2021 13:53:14       S001    Male   30  Right-handed
# 4    12/7/2021 13:33:54       S002  Female   19  Right-handed
# 5    12/8/2021 13:05:07       S003  Female   20  Right-handed
# 6    12/9/2021 13:55:45       S004  Female   19  Right-handed
# 7   12/14/2021 13:10:58       S005    Male   25  Right-handed
# 8    5/27/2022 12:46:49       M001    Male   29  Right-handed
# 9     6/7/2022 13:06:11       M002    Male   32  Right-handed
# 10    6/9/2022 12:25:52       M003  Female   21  Right-handed
# 11   6/13/2022 12:23:38       M004  Female   34  Right-handed
# 12   6/15/2022 15:54:12       M005    Male   21  Right-handed
# 13   6/27/2022 12:39:27       M006    Male   32  Right-handed
# 14   6/28/2022 13:10:02       M007  Female   21  Right-handed
# 15    7/1/2022 12:00:30       M008  Female   25  Right-handed
# 16   7/15/2022 12:52:39       M009    Male   29  Right-handed
# 17   7/18/2022 16:32:15       M010  Female   27  Right-handed
# 18   7/22/2022 11:29:23       M011    Male   26  Right-handed
# 19   7/25/2022 11:33:32       M012  Female   24  Right-handed
# 20   7/26/2022 11:58:22       M013  Female   19  Right-handed
# 21   7/28/2022 12:18:58       M014  Female   23  Right-handed
# 22   7/29/2022 15:39:33       M015  Female   20  Right-handed
# 23    8/1/2022 12:41:50       M016  Female   22  Right-handed
# 24    8/2/2022 15:21:05       M017  Female   20  Right-handed
# 25   8/10/2022 14:27:40       M018  Female   23  Right-handed
#
#    1. How familiar are you with this tool? [Please rate.]  \
# 0              I have never used it or heard about it
# 1              I have never used it or heard about it
# 2              I have never used it or heard about it
# 3             I have seen it once or twice in my life
# 4              I have never used it or heard about it
# 5              I have never used it or heard about it
# 6              I have never used it or heard about it
# 7                               I know that it exists
# 8              I have never used it or heard about it
# 9              I have never used it or heard about it
# 10             I have never used it or heard about it
# 11                              I know that it exists
# 12             I have never used it or heard about it
# 13             I have never used it or heard about it
# 14             I have never used it or heard about it
# 15             I have never used it or heard about it
# 16             I have never used it or heard about it
# 17             I have never used it or heard about it
# 18             I have never used it or heard about it
# 19             I have never used it or heard about it
# 20             I have never used it or heard about it
# 21             I have never used it or heard about it
# 22             I have never used it or heard about it
# 23             I have never used it or heard about it
# 24            I have seen it once or twice in my life
# 25                              I know that it exists
#
#    2. How familiar are you with this tool? [Please rate.]  \
# 0                    I see it every week or every day
# 1                    I see it every week or every day
# 2                    I see it every week or every day
# 3                    I see it every week or every day
# 4                    I see it every week or every day
# 5                    I see it every week or every day
# 6                    I see it every week or every day
# 7                    I see it every week or every day
# 8                    I see it every week or every day
# 9                    I see it every week or every day
# 10                   I see it every week or every day
# 11                   I see it every week or every day
# 12                   I see it every week or every day
# 13  I have seen it before, from once a year to onc...
# 14                   I see it every week or every day
# 15                   I see it every week or every day
# 16                   I see it every week or every day
# 17                   I see it every week or every day
# 18                   I see it every week or every day
# 19                   I see it every week or every day
# 20                   I see it every week or every day
# 21                   I see it every week or every day
# 22                   I see it every week or every day
# 23                   I see it every week or every day
# 24                   I see it every week or every day
# 25                   I see it every week or every day
#
#    3. How familiar are you with this tool? [Please rate.]  \
# 0   I have seen it before, from once a year to onc...
# 1                    I see it every week or every day
# 2   I have seen it before, from once a year to onc...
# 3                    I see it every week or every day
# 4   I have seen it before, from once a year to onc...
# 5                    I see it every week or every day
# 6   I have seen it before, from once a year to onc...
# 7                    I see it every week or every day
# 8   I have seen it before, from once a year to onc...
# 9   I have seen it before, from once a year to onc...
# 10  I have seen it before, from once a year to onc...
# 11                   I see it every week or every day
# 12  I have seen it before, from once a year to onc...
# 13                              I know that it exists
# 14  I have seen it before, from once a year to onc...
# 15  I have seen it before, from once a year to onc...
# 16  I have seen it before, from once a year to onc...
# 17  I have seen it before, from once a year to onc...
# 18                   I see it every week or every day
# 19  I have seen it before, from once a year to onc...
# 20  I have seen it before, from once a year to onc...
# 21                   I see it every week or every day
# 22  I have seen it before, from once a year to onc...
# 23  I have seen it before, from once a year to onc...
# 24  I have seen it before, from once a year to onc...
# 25            I have seen it once or twice in my life
#
#    4. How familiar are you with this tool? [Please rate.]  \
# 0   I have seen it before, from once a year to onc...
# 1                               I know that it exists
# 2             I have seen it once or twice in my life
# 3   I have seen it before, from once a year to onc...
# 4                               I know that it exists
# 5   I have seen it before, from once a year to onc...
# 6             I have seen it once or twice in my life
# 7                    I see it every week or every day
# 8              I have never used it or heard about it
# 9              I have never used it or heard about it
# 10             I have never used it or heard about it
# 11  I have seen it before, from once a year to onc...
# 12             I have never used it or heard about it
# 13             I have never used it or heard about it
# 14             I have never used it or heard about it
# 15             I have never used it or heard about it
# 16             I have never used it or heard about it
# 17             I have never used it or heard about it
# 18             I have never used it or heard about it
# 19             I have never used it or heard about it
# 20                              I know that it exists
# 21             I have never used it or heard about it
# 22             I have never used it or heard about it
# 23            I have seen it once or twice in my life
# 24  I have seen it before, from once a year to onc...
# 25             I have never used it or heard about it
#
#    5. How familiar are you with this tool? [Please rate.]  \
# 0              I have never used it or heard about it
# 1                               I know that it exists
# 2              I have never used it or heard about it
# 3   I have seen it before, from once a year to onc...
# 4                               I know that it exists
# 5              I have never used it or heard about it
# 6              I have never used it or heard about it
# 7              I have never used it or heard about it
# 8              I have never used it or heard about it
# 9              I have never used it or heard about it
# 10             I have never used it or heard about it
# 11                              I know that it exists
# 12             I have never used it or heard about it
# 13             I have never used it or heard about it
# 14            I have seen it once or twice in my life
# 15             I have never used it or heard about it
# 16            I have seen it once or twice in my life
# 17                              I know that it exists
# 18             I have never used it or heard about it
# 19             I have never used it or heard about it
# 20             I have never used it or heard about it
# 21             I have never used it or heard about it
# 22             I have never used it or heard about it
# 23             I have never used it or heard about it
# 24            I have seen it once or twice in my life
# 25                              I know that it exists
#
#    6. How familiar are you with this tool? [Please rate.]  \
# 0              I have never used it or heard about it
# 1              I have never used it or heard about it
# 2              I have never used it or heard about it
# 3             I have seen it once or twice in my life
# 4              I have never used it or heard about it
# 5                               I know that it exists
# 6              I have never used it or heard about it
# 7              I have never used it or heard about it
# 8              I have never used it or heard about it
# 9              I have never used it or heard about it
# 10             I have never used it or heard about it
# 11                              I know that it exists
# 12             I have never used it or heard about it
# 13             I have never used it or heard about it
# 14             I have never used it or heard about it
# 15             I have never used it or heard about it
# 16             I have never used it or heard about it
# 17             I have never used it or heard about it
# 18             I have never used it or heard about it
# 19             I have never used it or heard about it
# 20             I have never used it or heard about it
# 21             I have never used it or heard about it
# 22             I have never used it or heard about it
# 23             I have never used it or heard about it
# 24             I have never used it or heard about it
# 25             I have never used it or heard about it
#
#    7. How familiar are you with this tool? [Please rate.]  \
# 0   I have seen it before, from once a year to onc...
# 1                    I see it every week or every day
# 2   I have seen it before, from once a year to onc...
# 3                    I see it every week or every day
# 4   I have seen it before, from once a year to onc...
# 5                    I see it every week or every day
# 6   I have seen it before, from once a year to onc...
# 7                    I see it every week or every day
# 8   I have seen it before, from once a year to onc...
# 9   I have seen it before, from once a year to onc...
# 10  I have seen it before, from once a year to onc...
# 11                   I see it every week or every day
# 12  I have seen it before, from once a year to onc...
# 13  I have seen it before, from once a year to onc...
# 14  I have seen it before, from once a year to onc...
# 15  I have seen it before, from once a year to onc...
# 16                   I see it every week or every day
# 17  I have seen it before, from once a year to onc...
# 18                   I see it every week or every day
# 19  I have seen it before, from once a year to onc...
# 20  I have seen it before, from once a year to onc...
# 21  I have seen it before, from once a year to onc...
# 22  I have seen it before, from once a year to onc...
# 23  I have seen it before, from once a year to onc...
# 24  I have seen it before, from once a year to onc...
# 25  I have seen it before, from once a year to onc...
#
#    8. How familiar are you with this tool? [Please rate.]  \
# 0   I have seen it before, from once a year to onc...
# 1                    I see it every week or every day
# 2             I have seen it once or twice in my life
# 3                    I see it every week or every day
# 4                    I see it every week or every day
# 5   I have seen it before, from once a year to onc...
# 6   I have seen it before, from once a year to onc...
# 7                    I see it every week or every day
# 8   I have seen it before, from once a year to onc...
# 9   I have seen it before, from once a year to onc...
# 10  I have seen it before, from once a year to onc...
# 11                   I see it every week or every day
# 12  I have seen it before, from once a year to onc...
# 13            I have seen it once or twice in my life
# 14  I have seen it before, from once a year to onc...
# 15  I have seen it before, from once a year to onc...
# 16  I have seen it before, from once a year to onc...
# 17  I have seen it before, from once a year to onc...
# 18  I have seen it before, from once a year to onc...
# 19  I have seen it before, from once a year to onc...
# 20  I have seen it before, from once a year to onc...
# 21  I have seen it before, from once a year to onc...
# 22  I have seen it before, from once a year to onc...
# 23  I have seen it before, from once a year to onc...
# 24                   I see it every week or every day
# 25            I have seen it once or twice in my life
#
#    9. How familiar are you with this tool? [Please rate.]  \
# 0              I have never used it or heard about it
# 1              I have never used it or heard about it
# 2              I have never used it or heard about it
# 3              I have never used it or heard about it
# 4              I have never used it or heard about it
# 5              I have never used it or heard about it
# 6   I have seen it before, from once a year to onc...
# 7              I have never used it or heard about it
# 8              I have never used it or heard about it
# 9              I have never used it or heard about it
# 10             I have never used it or heard about it
# 11             I have never used it or heard about it
# 12             I have never used it or heard about it
# 13             I have never used it or heard about it
# 14             I have never used it or heard about it
# 15             I have never used it or heard about it
# 16             I have never used it or heard about it
# 17             I have never used it or heard about it
# 18             I have never used it or heard about it
# 19             I have never used it or heard about it
# 20             I have never used it or heard about it
# 21             I have never used it or heard about it
# 22             I have never used it or heard about it
# 23             I have never used it or heard about it
# 24             I have never used it or heard about it
# 25             I have never used it or heard about it
#
#    10. How familiar are you with this tool? [Please rate.]  \
# 0   I have seen it before, from once a year to onc...
# 1                    I see it every week or every day
# 2   I have seen it before, from once a year to onc...
# 3   I have seen it before, from once a year to onc...
# 4   I have seen it before, from once a year to onc...
# 5   I have seen it before, from once a year to onc...
# 6   I have seen it before, from once a year to onc...
# 7                    I see it every week or every day
# 8             I have seen it once or twice in my life
# 9   I have seen it before, from once a year to onc...
# 10            I have seen it once or twice in my life
# 11                   I see it every week or every day
# 12  I have seen it before, from once a year to onc...
# 13                              I know that it exists
# 14  I have seen it before, from once a year to onc...
# 15            I have seen it once or twice in my life
# 16  I have seen it before, from once a year to onc...
# 17  I have seen it before, from once a year to onc...
# 18            I have seen it once or twice in my life
# 19  I have seen it before, from once a year to onc...
# 20  I have seen it before, from once a year to onc...
# 21  I have seen it before, from once a year to onc...
# 22  I have seen it before, from once a year to onc...
# 23  I have seen it before, from once a year to onc...
# 24  I have seen it before, from once a year to onc...
# 25            I have seen it once or twice in my life
#
#    11. How familiar are you with this tool? [Please rate.]  \
# 0              I have never used it or heard about it
# 1              I have never used it or heard about it
# 2              I have never used it or heard about it
# 3             I have seen it once or twice in my life
# 4              I have never used it or heard about it
# 5   I have seen it before, from once a year to onc...
# 6              I have never used it or heard about it
# 7              I have never used it or heard about it
# 8              I have never used it or heard about it
# 9              I have never used it or heard about it
# 10             I have never used it or heard about it
# 11             I have never used it or heard about it
# 12             I have never used it or heard about it
# 13             I have never used it or heard about it
# 14             I have never used it or heard about it
# 15             I have never used it or heard about it
# 16            I have seen it once or twice in my life
# 17             I have never used it or heard about it
# 18             I have never used it or heard about it
# 19             I have never used it or heard about it
# 20                              I know that it exists
# 21             I have never used it or heard about it
# 22             I have never used it or heard about it
# 23             I have never used it or heard about it
# 24             I have never used it or heard about it
# 25             I have never used it or heard about it
#
#    12. How familiar are you with this tool? [Please rate.]
# 0                    I see it every week or every day
# 1                    I see it every week or every day
# 2                    I see it every week or every day
# 3                    I see it every week or every day
# 4                    I see it every week or every day
# 5                    I see it every week or every day
# 6                    I see it every week or every day
# 7                    I see it every week or every day
# 8                    I see it every week or every day
# 9                    I see it every week or every day
# 10                   I see it every week or every day
# 11                   I see it every week or every day
# 12                   I see it every week or every day
# 13                   I see it every week or every day
# 14                   I see it every week or every day
# 15                   I see it every week or every day
# 16                   I see it every week or every day
# 17                   I see it every week or every day
# 18                   I see it every week or every day
# 19                   I see it every week or every day
# 20                   I see it every week or every day
# 21                   I see it every week or every day
# 22                   I see it every week or every day
# 23                   I see it every week or every day
# 24                   I see it every week or every day
# 25                   I see it every week or every day

# %%
familiarity_df.rename(columns={'1. How familiar are you with this tool? [Please rate.]': 'Fishscaler', 
                               '2. How familiar are you with this tool? [Please rate.]': 'Spatula',
                               '3. How familiar are you with this tool? [Please rate.]': 'Wrench',
                               '4. How familiar are you with this tool? [Please rate.]': 'Daisy Grubber',
                               '5. How familiar are you with this tool? [Please rate.]': 'Palette Knife',
                               '6. How familiar are you with this tool? [Please rate.]': 'Flower Cutter',
                               '7. How familiar are you with this tool? [Please rate.]': 'Screwdriver',
                               '8. How familiar are you with this tool? [Please rate.]': 'Paintbrush',
                               '9. How familiar are you with this tool? [Please rate.]': 'Spoke Wrench',
                               '10. How familiar are you with this tool? [Please rate.]': 'Trowel',
                               '11. How familiar are you with this tool? [Please rate.]': 'Lemon Zester',
                               '12. How familiar are you with this tool? [Please rate.]': 'Fork',
                               'Participant ID': 'ParticipantID'
                              }, inplace=True)

# %%
familiarity_df.columns
# Out:
# Index(['Timestamp', 'Unnamed: 1', 'Gender', 'Age', 'Handedness', 'Fishscaler',
#        'Spatula', 'Wrench', 'Daisy Grubber', 'Palette Knife', 'Flower Cutter',
#        'Screwdriver', 'Paintbrush', 'Spoke Wrench', 'Trowel', 'Lemon Zester',
#        'Fork'],
#       dtype='object')

# %%
familiarity_df.rename(columns={'Unnamed: 1':'subject_id'}, inplace=True)

# %%
familiarity_df = familiarity_df.drop_duplicates(subset=['subject_id'], keep='first')

# %%
for index in range(familiarity_df.shape[1])[5:]:
       print('Column Number : ', index)
       # Select column by index position using iloc[]
       columnSeriesObj = familiarity_df.iloc[:, index]
       print('Column : ', columnSeriesObj.name)
# Out:
# Column Number :  5
# Column :  Fishscaler
# Column Number :  6
# Column :  Spatula
# Column Number :  7
# Column :  Wrench
# Column Number :  8
# Column :  Daisy Grubber
# Column Number :  9
# Column :  Palette Knife
# Column Number :  10
# Column :  Flower Cutter
# Column Number :  11
# Column :  Screwdriver
# Column Number :  12
# Column :  Paintbrush
# Column Number :  13
# Column :  Spoke Wrench
# Column Number :  14
# Column :  Trowel
# Column Number :  15
# Column :  Lemon Zester
# Column Number :  16
# Column :  Fork

# %%
familiarity_level = {'I have never used it or heard about it':'1', 
                     'I know that it exists':'2', 
                     'I have seen it once or twice in my life':'3',
                     'I have seen it before, from once a year to once a month':'4',
                     'I see it every week or every day':'5'
                    }

# %%
# for index in range(familiarity_df.shape[1])[5:]:
#     columnSeriesObj = familiarity_df.iloc[:, index]
#     familiarity_df[columnSeriesObj.name] = familiarity_df[columnSeriesObj.name].map(familiarity_level)
tools = ['Fishscaler', 'Spatula', 'Wrench', 'Daisy Grubber', 'Palette Knife',
       'Flower Cutter', 'Screwdriver', 'Paintbrush', 'Spoke Wrench', 'Trowel',
       'Lemon Zester', 'Fork']  
for col in familiarity_df.columns:
    if col in tools:
        familiarity_df[col] = familiarity_df[col].map(familiarity_level)
familiarity_df.head()
# Out:
#              Timestamp subject_id  Gender  Age    Handedness Fishscaler  \
# 0  11/17/2021 17:21:34       P002  Female   21  Right-handed          1
# 1  11/18/2021 17:21:02       P003  Female   23  Right-handed          1
# 2  11/19/2021 18:30:23       P004    Male   29  Right-handed          1
# 3   12/2/2021 13:53:14       S001    Male   30  Right-handed          3
# 4   12/7/2021 13:33:54       S002  Female   19  Right-handed          1
#
#   Spatula Wrench Daisy Grubber Palette Knife Flower Cutter Screwdriver  \
# 0       5      4             4             1             1           4
# 1       5      5             2             2             1           5
# 2       5      4             3             1             1           4
# 3       5      5             4             4             3           5
# 4       5      4             2             2             1           4
#
#   Paintbrush Spoke Wrench Trowel Lemon Zester Fork
# 0          4            1      4            1    5
# 1          5            1      5            1    5
# 2          3            1      4            1    5
# 3          5            1      4            3    5
# 4          5            1      4            1    5

# %%
familiarity_df = familiarity_df.loc[familiarity_df.subject_id.str.startswith('M')]
familiarity_df = familiarity_df.query('subject_id not in ["M001", "M002", "M003", "M004", "M005"]')

# %%
display(familiarity_df['Gender'].value_counts())
display(familiarity_df['Handedness'].value_counts())
# Out:
# Female    10
# Male       3
# Name: Gender, dtype: int64
# Right-handed    13
# Name: Handedness, dtype: int64

# %%
display(familiarity_df.head())
# Out:
#              Timestamp subject_id  Gender  Age    Handedness Fishscaler  \
# 13  6/27/2022 12:39:27       M006    Male   32  Right-handed          1
# 14  6/28/2022 13:10:02       M007  Female   21  Right-handed          1
# 15   7/1/2022 12:00:30       M008  Female   25  Right-handed          1
# 16  7/15/2022 12:52:39       M009    Male   29  Right-handed          1
# 17  7/18/2022 16:32:15       M010  Female   27  Right-handed          1
#
#    Spatula Wrench Daisy Grubber Palette Knife Flower Cutter Screwdriver  \
# 13       4      2             1             1             1           4
# 14       5      4             1             3             1           4
# 15       5      4             1             1             1           4
# 16       5      4             1             3             1           5
# 17       5      4             1             2             1           4
#
#    Paintbrush Spoke Wrench Trowel Lemon Zester Fork
# 13          3            1      2            1    5
# 14          4            1      4            1    5
# 15          4            1      3            1    5
# 16          4            1      4            3    5
# 17          4            1      4            1    5

# %%
def label_tools(tool):
    familiar_tools = ['Spatula', 'Wrench','Screwdriver', 'Paintbrush', 'Trowel', 'Fork'] 
    
    if tool in familiar_tools:
        return 'familiar'
    else:
        return 'unfamiliar'
    
ratings_df = (
    familiarity_df
#     .reset_index()
    .melt(id_vars = ('subject_id'), value_vars = tools, var_name='tool', value_name='familiarity_rating')
)
ratings_df['familiarity'] = ratings_df.tool.apply(label_tools)
ratings_df.familiarity_rating = ratings_df.familiarity_rating.astype(int)
ratings_df = ratings_df.query('subject_id not in ["M001", "M002", "M003", "M004", "M005"]') # removing pilot participants
ratings_df.head()
# Out:
#   subject_id        tool  familiarity_rating familiarity
# 0       M006  Fishscaler                   1  unfamiliar
# 1       M007  Fishscaler                   1  unfamiliar
# 2       M008  Fishscaler                   1  unfamiliar
# 3       M009  Fishscaler                   1  unfamiliar
# 4       M010  Fishscaler                   1  unfamiliar

# %%
ratings_df.groupby(['familiarity',]).agg({'familiarity_rating':['mean', 'std']})
# Out:
#             familiarity_rating
#                           mean       std
# familiarity
# familiar               4.25641  0.710513
# unfamiliar             1.25641  0.653381

# %%
tmpdf = (
    ratings_df
    .groupby(['subject_id', 'familiarity',], as_index=True)
    .familiarity_rating
    .mean()
    .reset_index()
    .pivot(index='subject_id', columns='familiarity', values='familiarity_rating')
    .reset_index()
)

scipy.stats.ttest_ind(tmpdf['familiar'], tmpdf['unfamiliar'])
# Out:
# Ttest_indResult(statistic=22.6569525753134, pvalue=1.0375887739326373e-17)

# %%
colors
# Out:
# [(0.2980392156862745, 0.4470588235294118, 0.6901960784313725),
#  (0.8666666666666667, 0.5176470588235295, 0.3215686274509804),
#  (0.3333333333333333, 0.6588235294117647, 0.40784313725490196),
#  (0.7686274509803922, 0.3058823529411765, 0.3215686274509804),
#  (0.5058823529411764, 0.4470588235294118, 0.7019607843137254),
#  (0.5764705882352941, 0.47058823529411764, 0.3764705882352941),
#  (0.8549019607843137, 0.5450980392156862, 0.7647058823529411)]

# %%
_, ax = plt.subplots(2, 1, figsize=(15,10), sharey=True)

sns.set(
    palette='muted', 
    context='talk', 
    style='ticks', 
    rc={'font.family':'DejaVu Sans', 'font.weight':'medium'}
)

colors = sns.color_palette(palette='deep', n_colors=7)

familiar_tools = ['Spatula', 'Wrench','Screwdriver', 'Paintbrush', 'Trowel', 'Fork', ]  


ax[0] = sns.stripplot(
    data=ratings_df.query("tool in @familiar_tools"),
    y='familiarity_rating',
    x='tool',
    color=colors[0],
    jitter=0.15,
    size=10,
    linewidth=1.5,
    alpha=0.15,
    ax=ax[0]
)

ax[0] = sns.pointplot(
    data=ratings_df.query("tool in @familiar_tools"),
    y='familiarity_rating',
    x='tool',  
    color=colors[0],
    join=False,
    ci='sd',
#     capsize=0.05,
    ax=ax[0]

)


ax[1] = sns.stripplot(
    data=ratings_df.query("tool not in @familiar_tools"),
    y='familiarity_rating',
    x='tool',  
     color=colors[3],
    jitter=0.15,
    size=10,
    linewidth=1.5,
    alpha=0.15,
    ax=ax[1]
)

ax[1] = sns.pointplot(
    data=ratings_df.query("tool not in @familiar_tools"),
    y='familiarity_rating',
    x='tool',  
    color=colors[3],
    join=False,
    ci='sd',
#     capsize=0.05,
    ax=ax[1]
)

ax[0].set(
    xlabel='',
    yticks=[1,2,3,4,5],
    yticklabels=familiarity_level.keys(),
    ylabel=''
)
ax[1].set(
    xlabel='Tool',
    yticks=[1,2,3,4,5],
    yticklabels=familiarity_level.keys(),
    ylabel=''
)
# ax.legend(bbox_to_anchor=[1, 1])
sns.despine(offset=10)

ax[0].legend([],[], frameon=False)
ax[1].legend([],[], frameon=False)



plt.savefig(f'./familiarity_rating.png', transparent=True, bbox_inches='tight')
